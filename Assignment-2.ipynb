# %% [markdown]
# # Question 1

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver= webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# Entering designation and Location 

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# Scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
# Scrapping job Location from the given page
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
# Scrapping company name from the given page
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft'] ")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
# Scrapping Job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
# Creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_title,'job_location': job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                         job_title                        job_location  \
# 0                    Data Analyst                 Bangalore/Bengaluru
# 1                    Data Analyst                 Bangalore/Bengaluru
# 2                    Data Analyst                 Bangalore/Bengaluru
# 3          Senior Data Analyst II                 Bangalore/Bengaluru
# 4            Project Data Analyst                 Bangalore/Bengaluru
# 5  Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
# 6                    Data Analyst     Temp. WFH - Bangalore/Bengaluru
# 7        Executive - Data Analyst                 Bangalore/Bengaluru
# 8                    Data Analyst                 Bangalore/Bengaluru
# 9                    Data Analyst                 Bangalore/Bengaluru
#
#                          company_name experience_required
# 0                       Shell Pvt Ltd             2-5 Yrs
# 1                       Shell Pvt Ltd             3-5 Yrs
# ...

# %% [markdown]
# # Question 2

# %%
# Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# Entering designation and Location 

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[3]/div[2]/div[1]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[3]/div[2]/div[1]/div/button/span[2]")
search.click()

# %%
job_t=[]
job_l=[]
company_n=[]
exp_required=[]

# %%
# Scraping job title from the given page
title_tag=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    t=i.text
    job_t.append(t)

# %%
# Scrapping job Location from the given page
location_tag=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tag[0:10]:
    l=i.text
    job_l.append(l)

# %%
# Scrapping company name from the given page
company_tag=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft'] ")
for i in company_tag[0:10]:
    comp=i.text
    company_n.append(comp)

# %%
# Scrapping Job Experience from the given page
experience_tag=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tag[0:10]:
    exp=i.text
    exp_required.append(exp)

# %%
print(len(job_t),len(job_l),len(company_n),len(exp_required))
# Out:
# 10 10 10 10

# %%
# Creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_t,'job_location': job_l,'company_name':company_n,'experience_required':exp_required})
df
# Out:
#                                       job_title  \
# 0              Analystics & Modeling Specialist
# 1                                     Accenture
# 2                                Data Scientist
# 3                                Data Scientist
# 4  Data & Analytics Lead, Geo Analytics - GAMMA
# 5            Weather and Climate Data Scientist
# 6                                Data Scientist
# 7                           Data Scientist - II
# 8                         Senior Data Scientist
# 9                          Manager-Data Science
#
#                                         job_location             company_name  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Tata Nexarc
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...            Tech Mahindra
# 2                  Bangalore/Bengaluru, Nagpur, Pune  Boston Consulting Group
# 3                                Bangalore/Bengaluru            Shell Pvt Ltd
# ...

# %% [markdown]
# # Question 3

# %%
# Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# Entering designation and Location 

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[6]")
search.click()

# %%
job_t1=[]
job_l1=[]
company_n1=[]
exp_required1=[]

# %%
# Scraping job title from the given page
title_t=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_t[0:10]:
    t1=i.text
    job_t1.append(t1)

# %%
# Scrapping job Location from the given page
location_t=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_t[0:10]:
    l1=i.text
    job_l1.append(l1)

# %%
# Scrapping company name from the given page
company_t=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft'] ")
for i in company_t[0:10]:
    comp1=i.text
    company_n1.append(comp1)

# %%
# Scrapping Job Experience from the given page
experience_t=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_t[0:10]:
    exp1=i.text
    exp_required1.append(exp1)

# %%
print(len(job_t1),len(job_l1),len(company_n1),len(exp_required1))
# Out:
# 10 10 10 10

# %%
# Creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_t1,'job_location': job_l1,'company_name':company_n1,'experience_required':exp_required1})
df
# Out:
#                                            job_title  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                  Data Scientist - Engine Algorithm
# 3                                     Data Scientist
# 4  Opening For Jr. Data Scientist with Tatras Dat...
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 8                                     Data Scientist
# 9                              SE/SSE-Data Scientist
#
#                                         job_location  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 3                                  Temp. WFH - Noida
# 4                                        Delhi / NCR
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# # Question 4

# %%
# Opening the Flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# Entering Product

Product=driver.find_element(By.CLASS_NAME,"_3704LK")
Product.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
Brand=[]
ProductDescription=[]
Price=[]
discount=[]

# %%
# Scraping brand name from the given page
Brand_names=driver.find_elements(By.XPATH,'//a[@class="_2WkVRV"]')
for i in Brand_names:
    brand=i.text
    Brand.append(brand)
Brand[0:100]
# Out:
# ['Silver Kartz',
#  'VINCENT CHASE',
#  'Elligator',
#  'Fastrack',
#  'LIZA ANGEL',
#  'PHENOMENAL',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Elligator',
#  'SHAAH COLLECTIONS',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Fastrack',
#  'Elligator',
#  'LIZA ANGEL',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'ROZZETTA CRAFT',
#  'New Specs',
#  'Elligator',
#  'VINCENT CHASE',
#  'PROVOGUE',
#  'SRPM',
#  'SUNBEE',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'VINCENT CHASE',
#  'PIRASO',
#  'Fastrack',
#  'hayden haiza',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'ROYAL SON',
#  'PROVOGUE',
#  'LIZA ANGEL',
#  'SUNBEE',
#  'Silver Kartz',
#  'VINCENT CHASE',
#  'Elligator',
#  'Fastrack',
#  'LIZA ANGEL',
#  'PHENOMENAL',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Elligator',
#  'SHAAH COLLECTIONS',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Fastrack',
#  'Elligator',
#  'LIZA ANGEL',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'ROZZETTA CRAFT',
# ...

# %%
# Scrapping Product Description from the given page
Product_Description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Product_Description:
    product=i.text
    ProductDescription.append(product)
ProductDescription[0:100]
# Out:
# ['UV Protection Clubmaster Sunglasses (53)',
#  'by Lenskart Polarized, UV Protection Cat-eye Sunglasses...',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Riding Glasses, Night Vision Spectacle Sunglasses (Fre...',
#  'UV Protection Retro Square Sunglasses (53)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'by Lenskart Polarized, UV Protection Rectangular Sungla...',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'Polarized, UV Protection Aviator Sunglasses (55)',
#  'UV Protection, Polarized Round Sunglasses (54)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (53)',
#  'UV Protection, Polarized Rectangular Sunglasses (Free S...',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
# ...

# %%
# Scrapping Price from the given page
price_tags=driver.find_elements(By.XPATH,"//a[@class='_30jeq3']")
for i in price_tags:
    p=i.text
    Price.append(p)
Price[0:100]
# Out:
# ['₹278',
#  '₹806',
#  '₹149',
#  '₹489',
#  '₹129',
#  '₹129',
#  '₹539',
#  '₹849',
#  '₹129',
#  '₹159',
#  '₹497',
#  '₹699',
#  '₹539',
#  '₹149',
#  '₹129',
#  '₹149',
#  '₹447',
#  '₹399',
#  '₹259',
#  '₹286',
#  '₹949',
#  '₹664',
#  '₹179',
#  '₹283',
#  '₹599',
#  '₹539',
#  '₹398',
#  '₹901',
#  '₹257',
#  '₹479',
#  '₹413',
#  '₹701',
#  '₹664',
#  '₹149',
#  '₹779',
#  '₹479',
#  '₹399',
#  '₹664',
#  '₹129',
#  '₹149',
#  '₹278',
#  '₹806',
#  '₹149',
#  '₹489',
#  '₹129',
#  '₹129',
#  '₹539',
#  '₹849',
#  '₹129',
#  '₹159',
#  '₹497',
#  '₹699',
#  '₹539',
#  '₹149',
#  '₹129',
#  '₹149',
#  '₹447',
#  '₹399',
#  '₹259',
#  '₹286',
#  '₹949',
#  '₹664',
#  '₹179',
#  '₹283',
#  '₹599',
#  '₹539',
#  '₹398',
#  '₹901',
#  '₹257',
#  '₹479',
#  '₹413',
#  '₹701',
#  '₹664',
#  '₹149',
#  '₹779',
#  '₹479',
#  '₹399',
#  '₹664',
#  '₹129',
#  '₹149',
#  '₹278',
#  '₹806',
#  '₹149',
#  '₹489',
#  '₹129',
#  '₹129',
#  '₹539',
#  '₹849',
#  '₹129',
#  '₹159',
# ...

# %%
# Scrapping job Location from the given page
discount_offer=driver.find_elements(By.XPATH,'//a[@class="_3Ay6Sb"]')
for i in discount_offer:
    d=i.text
    discount.append(d)
discount[0:100]
# Out:
# ['81% off',
#  '59% off',
#  '75% off',
#  '38% off',
#  '87% off',
#  '87% off',
#  '40% off',
#  '57% off',
#  '87% off',
#  '90% off',
#  '81% off',
#  '59% off',
#  '75% off',
#  '38% off',
#  '87% off',
#  '87% off',
#  '40% off',
#  '57% off',
#  '87% off',
#  '90% off',
#  '75% off',
#  '65% off',
#  '40% off',
#  '85% off',
#  '87% off',
#  '88% off',
#  '77% off',
#  '80% off',
#  '90% off',
#  '88% off',
#  '62% off',
#  '74% off',
#  '82% off',
#  '78% off',
#  '40% off',
#  '40% off',
#  '80% off',
#  '54% off',
#  '83% off',
#  '40% off',
#  '83% off',
#  '71% off',
#  '66% off',
#  '87% off',
#  '40% off',
#  '40% off',
#  '73% off',
#  '74% off',
#  '74% off',
#  '85% off']

# %%
print(len(Brand),len(ProductDescription),len(Price),len(discount))

# %%
# Creating the dataframe from above data-
df=pd.DataFrame({'Brand_Name':Brand,'Product_Description': ProductDescription,'Price':Price,'discount':discount})
df

# %% [markdown]
# # Question 5

# %%
# Opening the Flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
Next=driver.find_element(By.CLASS_NAME,"_1LKTO3")
Next.click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
# Scraping Rating from the given page
rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating[0:100]:
    r=i.text
    Rating.append(r)
    
Rating[0:100]
# Out:
# ['5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5']

# %%
# Scraping Review from the given page
review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review[0:100]:
    rev=i.text
    Review_summary.append(rev)
    
Review_summary[0:100]
# Out:
# ['Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Great product',
#  'Fabulous!',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Great product',
#  'Fabulous!',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Perfect product!',
#  'Value-for-money',
#  'Highly recommended',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Worth every penny',
#  'Highly recommended',
#  'Highly recommended',
#  'Perfect product!',
#  'Great product',
#  'Pretty good',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
# ...

# %%
# Scraping Rating from the given page
fullreview=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in fullreview[0:100]:
    fr=i.text
    Full_review.append(fr)
    
Full_review[0:100]
# Out:
# ['This is my first iOS phone. I am very happy with this product. Very much satisfied with this. I love this phone.',
#  'Best and amazing product.....phone looks so premium.... battary is also good as expected .... Wide angle camera is so addictive ...if you are a IOS lover....then this phone will be the best choice for you all!!💯🔥',
#  'i11 is worthy to buy, too much happy with the product. Thank u flipkart I received the item on time..loved it..',
#  'It’s a must buy who is looking for an upgrade from previous generation of iPhones. If you are using XR then still you can hold on for sometime and upgrade to 2020 model else this phone is a must buy . Camera quality is amazing and wide angle is something to count upon. Performance wise it’s amazing and feels premium while holding in hand. So a big YES for this device. Go for 128 GB variant as the 4K videos will occupy lots of space and the storage can get over very quickly. Try to buy it with...\nREAD MORE',
# ...

# %% [markdown]
# # Question 6

# %%
# Opening the Flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# Entering Product

Product=driver.find_element(By.CLASS_NAME,"_3704LK")
Product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
Brand1=[]
ProductDescription1=[]
Price1=[]
discount1=[]

# %%
# Scraping brand name from the given page
Brand_names1=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand_names1:
    brand1=i.text
    Brand1.append(brand1)
Brand1[0:100]
# Out:
# ['ANTA',
#  'aadi',
#  'Labbin',
#  'Shozie',
#  'aadi',
#  'SFR',
#  'SFR',
#  'RapidBox',
#  'TR',
#  'Kzaara',
#  'Mast & Harbour',
#  'ANTA',
#  'SFR',
#  'RapidBox',
#  'BRUTON',
#  'BRUTON',
#  'TR',
#  'TR',
#  'Labbin',
#  'Deals4you',
#  'ANTA',
#  'PUMA',
#  'SFR',
#  'Kraasa',
#  'SFR',
#  'BRUTON',
#  'PUMA',
#  'ANTA',
#  'World Wear Footwear',
#  'SCATCHITE',
#  'ANTA',
#  'ANTA',
#  'SFR',
#  'BRUTON',
#  'Shozie',
#  'Robbie jones',
#  'ANTA',
#  'ANTA',
#  'Rzisbo',
#  'BIRDE',
#  'ANTA',
#  'aadi',
#  'Labbin',
#  'Shozie',
#  'aadi',
#  'SFR',
#  'SFR',
#  'RapidBox',
#  'TR',
#  'Kzaara',
#  'Mast & Harbour',
#  'ANTA',
#  'SFR',
#  'RapidBox',
#  'BRUTON',
#  'BRUTON',
#  'TR',
#  'TR',
#  'Labbin',
#  'Deals4you',
#  'ANTA',
#  'PUMA',
#  'SFR',
#  'Kraasa',
#  'SFR',
#  'BRUTON',
#  'PUMA',
#  'ANTA',
#  'World Wear Footwear',
#  'SCATCHITE',
#  'ANTA',
#  'ANTA',
#  'SFR',
#  'BRUTON',
#  'Shozie',
#  'Robbie jones',
#  'ANTA',
#  'ANTA',
#  'Rzisbo',
# ...

# %%
# Scrapping Product Description from the given page
Product_Description1=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Product_Description1:
    product1=i.text
    ProductDescription1.append(product1)
ProductDescription1[0:100]
# Out:
# ['A-Shock Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Mesh | Ultralightweight | Comfortable | Breathable Walk...',
#  'FAST Trenddy Tainer Lace-ups Sporty Casuals Sneakers Fo...',
#  'PLANCK Smart Grey Lace-Ups Casuals Sneakers Sneakers Fo...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'WALKER Sneakers For Men',
#  'PLANCK Smart Red Lace-Ups Casuals Sneakers Sneakers For...',
#  'Sneakers For Men',
#  'Lightweight Pack Of 1 Trendy Sneakers Sneakers For Men',
#  'Lattest Sneakers Shoe Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Women',
#  'Sneakers For Men',
#  'Puma Flex Renew Sneakers For Men',
#  'Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'PLANCK Smart Blue Lace-Ups Casuals Sneakers Sneakers Fo...',
#  'Exclusive Sneaker Shoes Sneakers For Men',
#  'Skye Clean Distressed Sneakers For Women',
# ...

# %%
# Scrapping Price from the given page
price_tags1=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags1:
    p1=i.text
    Price1.append(p1)
Price1[0:100]
# Out:
# ['₹4,509',
#  '₹399',
#  '₹399',
#  '₹295',
#  '₹359',
#  '₹299',
#  '₹209',
#  '₹599',
#  '₹389',
#  '₹229',
#  '₹824',
#  '₹3,299',
#  '₹209',
#  '₹599',
#  '₹199',
#  '₹299',
#  '₹389',
#  '₹299',
#  '₹399',
#  '₹299',
#  '₹3,299',
#  '₹2,199',
#  '₹269',
#  '₹449',
#  '₹209',
#  '₹299',
#  '₹2,009',
#  '₹2,504',
#  '₹259',
#  '₹360',
#  '₹2,024',
#  '₹1,997',
#  '₹299',
#  '₹299',
#  '₹419',
#  '₹439',
#  '₹2,947',
#  '₹2,863',
#  '₹549',
#  '₹349',
#  '₹4,509',
#  '₹399',
#  '₹399',
#  '₹295',
#  '₹359',
#  '₹299',
#  '₹209',
#  '₹599',
#  '₹389',
#  '₹229',
#  '₹824',
#  '₹3,299',
#  '₹209',
#  '₹599',
#  '₹199',
#  '₹299',
#  '₹389',
#  '₹299',
#  '₹399',
#  '₹299',
#  '₹3,299',
#  '₹2,199',
#  '₹269',
#  '₹449',
#  '₹209',
#  '₹299',
#  '₹2,009',
#  '₹2,504',
#  '₹259',
#  '₹360',
#  '₹2,024',
#  '₹1,997',
#  '₹299',
#  '₹299',
#  '₹419',
#  '₹439',
#  '₹2,947',
#  '₹2,863',
#  '₹549',
#  '₹349']

# %% [markdown]
# # Question 7

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver= webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32 (2)\chromedriver.exe")

# %%
# Opening the Amazon page on automated chrome browser
driver.get('https://www.amazon.in/')

# %%
# Entering Product
Product=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute ")
Product.send_keys('Laptop')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [193], in <cell line: 2>()
#       1 # Entering Product
# ----> 2 Product=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute ")
#       3 Product.send_keys('Laptop')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"nav-search-submit-text nav-sprite nav-progressive-attribute")
search.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [187], in <cell line: 1>()
# ----> 1 search=driver.find_element(By.CLASS_NAME,"nav-search-submit-text nav-sprite nav-progressive-attribute")
#       2 search.click()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
# ...

# %% [markdown]
# # Question 8

# %%
# Opening the Amazon page on automated chrome browser
driver.get('https://www.azquotes.com/')

# %%
Quote=[]
Author=[]
TypeOfQuotes=[]

# %%
# Scrapping Quote from the given page
quote=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote[0:1000]:
    q=i.text
    Quote.append(q)
Quote
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
# Scrapping Author from the given page
author=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author[0:1000]:
    a=i.text
    Author.append(a)
Author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers',
#  'Jimmy Carter',
#  'Albert Einstein',
#  'Abraham Lincoln',
#  'Steven Weinberg',
#  'Franklin D. Roosevelt',
#  'Albert Einstein',
#  'Maya Angelou',
#  'Mark Twain',
#  'Theodore Roosevelt',
#  'Michael Jackson',
#  'Martin Luther King, Jr.',
#  'C. S. Lewis',
#  'Theodore Roosevelt',
#  'Mark Twain',
#  'Abraham Lincoln',
#  'Ruth Graham',
#  'C. S. Lewis',
#  'Groucho Marx',
#  'John Lennon',
#  'Barbara Bush',
#  'Albert Einstein',
#  'Francis Chan',
#  'Henry Ford',
#  'Victor Hugo',
#  'Abu Bakr',
#  'Zig Ziglar',
#  'Winston Churchill',
#  'Zig Ziglar',
#  'John F. Kennedy',
#  'Dwight D. Eisenhower',
#  'Winston Churchill',
#  'Albert Einstein',
#  'Willie Nelson',
#  'Johnny Cash',
#  'Marie Curie',
#  'Maya Angelou',
#  'Amy Bloom',
#  'Zig Ziglar',
#  'John Lennon',
# ...

# %%
#Scrapping Type of Quote from the given page
toq=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in toq[0:1000]:
    t=i.text
    TypeOfQuotes.append(t)
TypeOfQuotes
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %% [markdown]
# # Question 9

# %%
# Opening the Amazon page on automated chrome browser
driver.get('https://www.jagranjosh.com/')

# %%
#Scrapping Type of Name from the given page
name=[]
Name=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[2]/p/strong/a')
for i in Name[0:1000]:
    n=i.text
    name.append(n)
name

# %%
#Scrapping Born-Dead from the given page
toq=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in toq[0:1000]:
    t=i.text
    TypeOfQuotes.append(t)
TypeOfQuotes

# %%
#Scrapping Type of Term of office from the given page 
toq=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in toq[0:1000]:
    t=i.text
    TypeOfQuotes.append(t)
TypeOfQuotes

# %%
#Scrapping remarks from the given page
toq=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in toq[0:1000]:
    t=i.text
    TypeOfQuotes.append(t)
TypeOfQuotes

# %% [markdown]
# # Question 10

# %%
# Opening the Amazon page on automated chrome browser
driver.get('https://www.motor1.com/')
